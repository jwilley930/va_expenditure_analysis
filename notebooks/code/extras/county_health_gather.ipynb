# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import OneHotEncoder


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
addi = pd.read_excel('../data/raw_data/2021 County Health Rankings Data - v1mmerge.xlsx', sheet_name='Additional Measure Data' )#, 'Ranked Measure Data'])

# %%
ran = pd.read_excel('../data/raw_data/2021 County Health Rankings Data - v1mmerge.xlsx', sheet_name='Ranked Measure Data' )#, 'Ranked Measure Data'])

# %%
ran.head()
# Out:
#    FIPS    State   County  % Smokers  % Adults with Obesity  \
# 0  1001  Alabama  Autauga  19.810766                   33.0
# 1  1003  Alabama  Baldwin  18.513318                   30.0
# 2  1005  Alabama  Barbour  25.530768                   41.2
# 3  1007  Alabama     Bibb  23.084813                   37.4
# 4  1009  Alabama   Blount  22.954959                   33.0
#
#    % Physically Inactive  % Excessive Drinking  % Severe Housing Problems
# 0                   30.6             14.473886                  13.630967
# 1                   24.7             18.736958                  12.996651
# 2                   28.0             12.466974                  13.710555
# 3                   33.4             15.420603                   9.255242
# 4                   33.3             15.833284                  10.125665

# %%
addi.head()
# Out:
#    FIPS    State   County  Population  % Adults with Diabetes  \
# 0  1001  Alabama  Autauga       55869                    12.7
# 1  1003  Alabama  Baldwin      223234                    10.3
# 2  1005  Alabama  Barbour       24686                    17.5
# 3  1007  Alabama     Bibb       22394                    13.6
# 4  1009  Alabama   Blount       57826                    14.6
#
#    % Food Insecure  % Limited Access to Healthy Foods  % Uninsured  \
# 0             15.6                          11.991125    13.007961
# 1             12.9                           5.424427    16.753438
# 2             21.9                          10.739667    17.673231
# 3             15.1                           2.601627    13.429904
# 4             13.6                           2.880150    17.934702
#
#    % Less Than 18 Years of Age  % 65 and Over    % Rural
# 0                    23.206071      15.973080  42.002162
# 1                    21.302311      20.977987  42.279099
# ...

# %%
addi[addi['County'].isin(ran['County']) == False].head()
# Out:
# Empty DataFrame
# Columns: [FIPS, State, County, Population, % Adults with Diabetes, % Food Insecure, % Limited Access to Healthy Foods, % Uninsured, % Less Than 18 Years of Age, % 65 and Over, % Rural]
# Index: []

# %%
ran[ran['County'].isin(addi['County']) == False].head()
# Out:
# Empty DataFrame
# Columns: [FIPS, State, County, % Smokers, % Adults with Obesity, % Physically Inactive, % Excessive Drinking, % Severe Housing Problems]
# Index: []

# %%
health = pd.merge(ran, addi, how='inner', on=['State', 'County'])

# %%
health.head()
# Out:
#    FIPS_x    State   County  % Smokers  % Adults with Obesity  \
# 0    1001  Alabama  Autauga  19.810766                   33.0
# 1    1003  Alabama  Baldwin  18.513318                   30.0
# 2    1005  Alabama  Barbour  25.530768                   41.2
# 3    1007  Alabama     Bibb  23.084813                   37.4
# 4    1009  Alabama   Blount  22.954959                   33.0
#
#    % Physically Inactive  % Excessive Drinking  % Severe Housing Problems  \
# 0                   30.6             14.473886                  13.630967
# 1                   24.7             18.736958                  12.996651
# 2                   28.0             12.466974                  13.710555
# 3                   33.4             15.420603                   9.255242
# 4                   33.3             15.833284                  10.125665
#
#    FIPS_y  Population  % Adults with Diabetes  % Food Insecure  \
# 0    1001       55869                    12.7             15.6
# ...

# %%
health.drop(columns = ['FIPS_x', 'FIPS_y'], inplace = True)

# %%
health.head()
# Out:
#      State   County  % Smokers  % Adults with Obesity  % Physically Inactive  \
# 0  Alabama  Autauga  19.810766                   33.0                   30.6
# 1  Alabama  Baldwin  18.513318                   30.0                   24.7
# 2  Alabama  Barbour  25.530768                   41.2                   28.0
# 3  Alabama     Bibb  23.084813                   37.4                   33.4
# 4  Alabama   Blount  22.954959                   33.0                   33.3
#
#    % Excessive Drinking  % Severe Housing Problems  Population  \
# 0             14.473886                  13.630967       55869
# 1             18.736958                  12.996651      223234
# 2             12.466974                  13.710555       24686
# 3             15.420603                   9.255242       22394
# 4             15.833284                  10.125665       57826
#
#    % Adults with Diabetes  % Food Insecure  % Limited Access to Healthy Foods  \
# ...

# %%
health.to_excel('../data/raw_data/2021 County Health Rankings Data - v1-copy.xlsx')
