# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)

# %%
disability_county = pd.read_csv('../data/raw_data/FY_2020_Disability_Compensation_Recipients_by_County.csv')

# %%
disability_county.isna().sum()
# Out:
# FIPS code                                     44
# State                                          0
# County Name                                    0
# Total: Disability Compensation Recipients     44
# SCD rating: 0% to 20%                        155
# SCD rating: 30% to 40%                       320
# SCD rating: 50% to 60%                       348
# SCD rating: 70% to 90%                       210
# SCD rating: 100%                             335
# Age: 17-44                                   276
# Age: 45-64                                   273
# Age: 65 or older                              75
# Male                                         655
# Female                                       655
# dtype: int64

# %%
disability_county.head()
# Out:
#    FIPS code    State County Name  Total: Disability Compensation Recipients  \
# 0     1001.0  Alabama     Autauga                                     2000.0
# 1     1003.0  Alabama     Baldwin                                     5073.0
# 2     1005.0  Alabama     Barbour                                      605.0
# 3     1007.0  Alabama        Bibb                                      278.0
# 4     1009.0  Alabama      Blount                                      771.0
#
#    SCD rating: 0% to 20%  SCD rating: 30% to 40%  SCD rating: 50% to 60%  \
# 0                  435.0                   270.0                   278.0
# 1                 1524.0                   774.0                   772.0
# 2                  111.0                    75.0                   110.0
# 3                   61.0                    47.0                    38.0
# 4                  201.0                   122.0                   119.0
#
# ...

# %%
disability_county = disability_county[disability_county['FIPS code'].isna() == False] 
disability_county = disability_county[disability_county['Total: Disability Compensation Recipients'].isna() == False]

# %%
disability_county[disability_county['SCD rating: 0% to 20%'].isna() == True].head()
# Out:
#      FIPS code       State         County Name  \
# 72      2060.0      Alaska         Bristol Bay
# 83      2164.0      Alaska  Lake And Peninsula
# 91      2230.0      Alaska             Skagway
# 172     5117.0    Arkansas             Prairie
# 191     6003.0  California              Alpine
#
#      Total: Disability Compensation Recipients  SCD rating: 0% to 20%  \
# 72                                        18.0                    NaN
# 83                                        16.0                    NaN
# 91                                        14.0                    NaN
# 172                                      105.0                    NaN
# 191                                       13.0                    NaN
#
#      SCD rating: 30% to 40%  SCD rating: 50% to 60%  SCD rating: 70% to 90%  \
# 72                      NaN                     NaN                     NaN
# 83                      NaN                     NaN                     NaN
# ...

# %%
health_spending = pd.read_excel('../data/raw_data/GDX_FY20.xlsx')
health_spending.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 11 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   State                                              54 non-null     object
#  1   Veteran Population*                                54 non-null     float64
#  2   Total Expenditure                                  54 non-null     float64
#  3   Compensation & Pension                             54 non-null     float64
#  4   Construction                                       54 non-null     float64
#  5   Education & Vocational Rehabilitation/ Employment  54 non-null     float64
#  6   Loan Guaranty#                                     54 non-null     float64
#  7   General Operating Expenses                         54 non-null     float64
# ...

# %%
health_spending = health_spending[['State', 'Veteran Population*', 'Unique Patients **', 'Medical Care']].head(52)
health_spending.columns = ['state', 'total_veterans', 'vets_using_va_healthcare', 'medical_expenditure_thousands']

# %%
health_spending.head()
# Out:
#            state  total_veterans  vets_using_va_healthcare  \
# 0  United States    1.946570e+07                   6108277
# 1        Alabama    3.629009e+05                    115440
# 2         Alaska    6.938363e+04                     21685
# 3        Arizona    5.044514e+05                    163613
# 4       Arkansas    2.025173e+05                     83510
#
#    medical_expenditure_thousands
# 0                   8.680791e+07
# 1                   1.445770e+06
# 2                   4.175775e+05
# 3                   2.308161e+06
# 4                   1.208500e+06

# %%
health_spending.to_csv('../data/health_spending.csv', index=False)
